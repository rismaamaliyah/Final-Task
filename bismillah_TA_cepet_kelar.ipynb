# %% [markdown]
# <a href="https://colab.research.google.com/github/rismaamaliyah/tugas-akhir/blob/main/bismillah_TA_cepet_kelar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Data**

# %%
import pandas as pd
from google.colab import files

# %%
data = 'https://raw.githubusercontent.com/rismaamaliyah/tugas-akhir/main/dataset%20fixed.csv'
df = pd.read_csv(data)
df
# Out:
#                            Date  \
# 0     2023-05-17 23:16:06+00:00
# 1     2023-05-17 21:54:33+00:00
# 2     2023-05-17 21:10:00+00:00
# 3     2023-05-17 21:10:00+00:01
# 4     2023-05-17 19:40:46+00:00
# ...                         ...
# 5000  2023-05-09 09:43:36+00:00
# 5001  2023-05-09 09:42:08+00:00
# 5002  2023-05-09 09:30:40+00:00
# 5003  2023-05-09 09:30:20+00:00
# 5004  2023-05-09 09:20:46+00:00
#
#                                                   Tweet  Sentiment
# 0     Rekrutmen berdasarkan identitas bukan kualitas...          0
# 1     BSI (BRIS) terancam sanksi UU Perlindungan Dat...          0
# 2     @bankbsi_id Alhamdulillah rekening saya sudah ...          1
# 3     @bankbsi_id gila sampe hari ini pun tetep begi...          0
# 4     @sayit_uwu @joodieth @F2aldi @bankbsi_id Balik...          1
# ...                                                 ...        ...
# 5000  Sumpah kecewa banget sama BSI @bankbsi_id ini ...          0
# ...

# %%
df.drop(['Date'],axis=1,inplace=True)
df.head()
# Out:
#                                                Tweet  Sentiment
# 0  Rekrutmen berdasarkan identitas bukan kualitas...          0
# 1  BSI (BRIS) terancam sanksi UU Perlindungan Dat...          0
# 2  @bankbsi_id Alhamdulillah rekening saya sudah ...          1
# 3  @bankbsi_id gila sampe hari ini pun tetep begi...          0
# 4  @sayit_uwu @joodieth @F2aldi @bankbsi_id Balik...          1

# %% [markdown]
# # **Pre-processing**

# %%
pip install nltk

# %%
import re
import string
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

cleaned_tweets = []
for index, row in df.iterrows():
    tweet = row['Tweet']

    # Case folding
    tweet = tweet.casefold()

    # Cleaning data
    # Hapus tanda @
    tweet = re.sub(r'@[\w]*', '', tweet)
    # Hapus karaketr non-alphanumerik
    tweet = re.sub(r'[^\w\s]', '', tweet)
    # Hapus karakter selain huruf, angka, dan spasi dari teks tweet
    tweet = re.sub(r'[^a-zA-Z0-9\s]', '', tweet)
    # Hapus URL
    tweet = re.sub(r'http\S+|www\S+|ftp\S+', '', tweet)
    # Hapus emoji
    tweet = re.sub(r'[^\x00-\x7F]+', '', tweet)

    # Tokenization
    tokens = word_tokenize(tweet)

    # Stopwords removal
    stop_words = set(stopwords.words('indonesian'))
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

    # Stemming
    stemmed_tokens = [stemmer.stem(word) for word in tokens]

    cleaned_tweets.append(stemmed_tokens)

df['Tweet'] = cleaned_tweets
df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                   Tweet  Sentiment
# 0     [rekrutmen, berdasarkan, identita, bukan, kual...          0
# 1     [bsi, bri, terancam, sanksi, uu, perlindungan,...          0
# 2     [alhamdulillah, reken, saya, sudah, aman, kare...          1
# 3     [gila, samp, hari, ini, pun, tetep, begini, ni...          0
# 4     [balik, lagi, ke, bsi, karena, transaksi, gaga...          1
# ...                                                 ...        ...
# 5000  [sumpah, kecewa, banget, sama, bsi, ini, masa,...          0
# 5001  [pov, programm, bsi, rn, uwu, semangat, kalian...          1
# 5002  [udah, kak, mobil, bsi, udah, bisa, barusan, a...          1
# 5003  [sebaiknya, buat, akun, bank, syariah, lainnya...          0
# ...

# %% [markdown]
# # **Pembagian Data**

# %%
y = df['Sentiment']

# %%
from sklearn.model_selection import train_test_split

# train_data, temp_data = train_test_split(df['Tweet'], y, test_size=0.3, random_state=42)
# validation_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)
# # (70% data pelatihan, 15% data validasi, 15% data pengujian)

x_train, x_test, y_train, y_test = train_test_split(df['Tweet'], y, test_size=0.3, random_state=42)

# Cetak beberapa baris data dari set pelatihan
print("Data Pelatihan:")
print(x_train.head())

# Cetak beberapa baris data dari set pengujian
print("\nData Pengujian:")
print(x_test.head())
# Out:
# Data Pelatihan:
# 321     [di, prank, sama, bank, lebih, sakit, udah, ce...
# 1784                  [pantass, buat, trf, gagal, mulukk]
# 1519    [data, kami, terancam, dan, anda, dengan, sant...
# 2850                            [ga, bisa, transfer, ini]
# 2384    [cuman, bisa, buat, cek, saldo, sama, transfer...
# Name: Tweet, dtype: object
#
# Data Pengujian:
# 3704    [setelah, per, drama, an, bsi, ber, hari, hari...
# 3253    [ini, gimanasi, sampai, hari, ini, transaksi, ...
# 4420    [min, tolonglah, tim, cybersecuritynya, kerjan...
# 4883    [bikin, trauma, nasabah, sekali, bisa, systemn...
# 4225    [iya, nih, belum, sempet, mindahin, saldo, dar...
# Name: Tweet, dtype: object

# %% [markdown]
# # **Word Embedding**

# %%
pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# train_texts = train_data.tolist()
# test_texts = test_data.tolist()

# Definisikan parameter Word Embedding
vocab_size = 10000

# 1. Inisialisasi dan fit Tokenizer
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(x_train)

# 2. Konversi teks ke urutan angka
train_sequences = tokenizer.texts_to_sequences(x_train)
test_sequences = tokenizer.texts_to_sequences(x_test)

word2vec=tokenizer.word_index
V=len(word2vec)
print('dataset has %s number of independent tokens' %V)

# 3. Pemotongan atau Padding (jika diperlukan)
train_sequences = pad_sequences(train_sequences)
test_sequences = pad_sequences(test_sequences, maxlen=train_sequences.shape[1])

print(train_sequences.shape)
print(test_sequences.shape)

embedding_size = len(tokenizer.word_index)
# sequence_length = 50

# Membuat model Word Embedding
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_size)
])

# Menggunakan model Word Embedding untuk mengonversi urutan angka menjadi vektor numerik
embedded_train_data = model.predict(train_sequences)
embedded_test_data = model.predict(test_sequences)
print(embedded_train_data.shape)
print(embedded_test_data.shape)
# Out:
# dataset has 7771 number of independent tokens
# (3503, 196)
# (1502, 196)
#  59/110 [===============>..............] - ETA: 4s

# %%
# print(embedded_train_data.shape)
# print(embedded_validation_data.shape)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, Flatten, Dense, Input, GlobalMaxPooling1D

model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size))
model.add(Conv1D(100, 5, activation='relu', padding='same'))
model.add(MaxPooling1D(5))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.summary()

# D=20
# i=Input((train_sequences.shape[1],))
# x=Embedding(V+1,D)(i)
# x=Conv1D(32,3,activation='relu')(x)
# x=MaxPooling1D(3)(x)
# x=Conv1D(64,3,activation='relu')(x)
# x=MaxPooling1D(3)(x)
# x=Conv1D(128,3,activation='relu')(x)
# x=GlobalMaxPooling1D()(x)
# x=Dense(5,activation='softmax')(x)
# model=Model(i,x)
# model.summary()

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# model.fit(embedded_train_data, train_data['Sentiment'], epochs=10, batch_size=64, validation_data=(embedded_validation_data, validation_data['Sentiment']))
model.fit(train_sequences, y_train, epochs=10, batch_size=100, validation_data=(test_sequences, y_test))

# %%
import numpy as np

# %%
y_pred = model.predict(test_sequences)
y_pred

# %%
y_pred=np.argmax(y_pred,axis=1)
y_pred

# %%
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns

cm=confusion_matrix(y_test,y_pred)
ax=sns.heatmap(cm,annot=True,cmap='Blues',fmt=' ')
ax.set_title('Confusion Matrix')
ax.set_xlabel('y_test')
ax.set_ylabel('y_pred')

# %%
print(classification_report(y_test,y_pred))
